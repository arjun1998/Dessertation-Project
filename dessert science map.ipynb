# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.chrome.options import Options
import time

options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\arjun\Downloads\dataset",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})


#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:/Users/arjun/Downloads/chromedriver-win64/chromedriver-win64/chromedriver")

#implicit wait
driver.implicitly_wait(0.5)
#maximize browser
driver.maximize_window()
#launch URL
driver.get("https://www.sciencedirect.com/journal/scientific-african/vol/19/suppl/C")
#driver.get("https://www.sciencedirect.com/user/login?targetURL=%2Fjournal%2Fscientific-african%2Fvol%2F15%2Fsuppl%2FC&from=globalheader")
# driver.find_element_by_id("bdd-email").send_keys("dwarkesh.game@gmail.com")
# driver.find_element_by_id("bdd-elsPrimaryBtn").click()
# time.sleep(5)
# driver.find_element_by_id("bdd-password").send_keys("Test@123")
# driver.find_element_by_id("bdd-elsPrimaryBtn").click()
time.sleep(5)
driver.find_element_by_css_selector('button.button-link.button-link-secondary.js-select-all').click()


driver.find_element_by_css_selector('button.button-alternative.text-s.u-margin-s-top.u-display-block.js-download-pdfs-button.button-alternative-primary').click()
#driver.get("https://www.sciencedirect.com/user/logout?targetURL=%2Fjournal%2Fscientific-african%2Fvol%2F15%2Fsuppl%2FC")




# l=driver.find_elements_by_xpath("//*[contains(text(), 'Download full issue')]")[0].click()
# l.click()
#identify element
#l =driver.find_element_by_css_selector('button.button-link.button-link-secondary.js-select-all')
#perform click
#l.click()
print("Page title is: ")
print(driver.title)
#close browser
#driver.quit()
# Out:
# Page title is:
# Scientific African | Vol 19, March 2023 | ScienceDirect.com by Elsevier

# %%
import selenium 
selenium.__version__
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)

# %%
import tabula

# Read PDF into list of DataFrame
dataframe = tabula.read_pdf(r"C:\Users\arjun\Downloads\dataset\A-first-report-on-the-identification-of-a-novel-archaea--Methan_2022_Scienti.pdf", pages='all')

print(dataframe[0])
# Out:
#                       with molecular-based methods to      allow  \
# 0                    sented by this approach has been  massively
# 1                  elucidate the diversity (number of        NaN
# 2                  number and distribution of species        NaN
# 3                    sequencing of the 16S rRNA gene.        The
# 4         rapid identification of microbial phylogeny        NaN
# 5                    1500bp with highly conserved and        NaN
# 6   approximately ubiquitous in all bacterial memb...        NaN
# 7   in investigating microbial deterioration of pa...        NaN
# 8            method to assess the microbial community        NaN
# 9                the use of metagenomics in profiling        NaN
# 10               for the first time in Nigeria to the       best
# 11            metagenomics in analyzing the microbial        NaN
# 12                  mass-spectrometry to identify the  different
# ...

# %%
dataframe[0]
# Out:
#                       with molecular-based methods to      allow  \
# 0                    sented by this approach has been  massively
# 1                  elucidate the diversity (number of        NaN
# 2                  number and distribution of species        NaN
# 3                    sequencing of the 16S rRNA gene.        The
# 4         rapid identification of microbial phylogeny        NaN
# 5                    1500bp with highly conserved and        NaN
# 6   approximately ubiquitous in all bacterial memb...        NaN
# 7   in investigating microbial deterioration of pa...        NaN
# 8            method to assess the microbial community        NaN
# 9                the use of metagenomics in profiling        NaN
# 10               for the first time in Nigeria to the       best
# 11            metagenomics in analyzing the microbial        NaN
# 12                  mass-spectrometry to identify the  different
# ...

# %%
import PyPDF2
import re

pdfFileObj = open(r"C:\Users\arjun\Downloads\dataset\A-first-report-on-the-identification-of-a-novel-archaea--Methan_2022_Scienti.pdf", 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
num_pages = pdfReader.numPages      
count = 0
pagecontent = ""                                                   
while count < num_pages: #The while loop will read each page
    #print(count)
    pageObj = pdfReader.getPage(count)
    count +=1
    pagecontent += pageObj.extractText()

print(pagecontent)
def between(value, a, b):
    # Find and validate before-part.
    pos_a = value.find(a)
    if pos_a == -1: return ""
    # Find and validate after part.
    pos_b = value.rfind(b)
    if pos_b == -1: return ""
    # Return middle part.
    adjusted_pos_a = pos_a + len(a)
    if adjusted_pos_a >= pos_b: return ""
    return value[adjusted_pos_a:pos_b]

desired = between(pagecontent,"Culture-dependent","Keywords")

text = desired.encode('ascii','ignore').lower() # It returns an utf-8 encoded version of the string & Lowercasing each word
text = text.decode('ISO-8859-1')
keywords = re.findall(r'[a-zA-Z]\w+',text)
#print(keywords)
#print('The abstract of the document is :' + desired)
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Scientiﬁc  African 15 (2022) e01029
# Contents  lists available  at ScienceDirect
# Scientiﬁc  African
# journal  homepage:  www.elsevier.com/locate/sciaf
# A ﬁrst report  on the identiﬁcation  of a novel  archaea,
# Methanospirillum  lacunae  from  spoilt  paints  in Lagos,  Nigeria
# using  a metagenomic  approach
# Obidi  F. Olayide  a , ∗, Kade E. Ayomikun  a , Fadipe  O. Temitope  b
# a Department  of Microbiology,  Faculty of Science, University  of Lagos, Akoka-Yaba,  Lagos, Nigeria
# b Biotechnology  Department,  Federal Institute of Industrial  Research,  Oshodi, Lagos, Nigeria
# a r t i c l e i n f o
# Article history:
# Received  9 December  2020
# Revised 23 October 2021
# Accepted  25 October 2021
# Editor DR B Gyampoh
# Keywords:
# Paints
# Metagenomics
# Archaea
# GC–MS
# Culture-dependent  a b s t r a c t
# ...

# %%
sub1='a b s t r a c t'
sub2='Introduction'
intro= ''.join(pagecontent.split(sub1)[1].split(sub2)[0])
introduction=[]
introduction.append(intro)
print(introduction)
# Out:
# [' \nPaint deterioration  is a serious esthetic  and economic  concern  attributed  to microbial  ac- \ntivity.Identifying  these microbes  is crucial to mitigating  their deleterious  effects. This paper \nassessed  the bacterial  community  and population  of fresh and spoilt water-based  paints \nfrom a reputable  paint company  in Lagos, Nigeria using culture-dependent  and metage-  \nnomic approaches.  Gas Chromatography  Mass Spectrophotometry  (GCMS)  was used to elu- \ncidate components  of the samples  . The bacterial  population  ranged from 1.4 ×10 6 to \n4.4 ×10 8 and from 2.3 ×10 6 to 6.8 ×10 8 CFU/ml in fresh and spoilt samples  respec- \ntively. Culture-based  technique  revealed  Bacillus spp. as the dominant  bacteria  in fresh \npaint along with Paenibacillus  macerans,  Corynebacterium  striatum,  Enterobacter  cloacae and \nClostridium  sphenoides  while Pseudomonas  spp. were predominant  in spoilt paints together  \nwith Arthrobacter  globiformis,  Azotobacter  
# ...

# %%
import glob
import os
print(glob.glob("/Users/arjun/Downloads/*.pdf"))
file_list=glob.glob("/Users/arjun/Downloads/dataset/*.pdf")
import PyPDF2
import re
fullcontent=[]
for j in file_list: 
    #pdfFileObj = open(r"C:\Users\arjun\Downloads\dataset\A-first-report-on-the-identification-of-a-novel-archaea--Methan_2022_Scienti.pdf", 'rb')
    pdfReader = PyPDF2.PdfFileReader(j)
    num_pages = pdfReader.numPages      
    count = 0
    pagecontent = ""                                                   
    while count < num_pages: #The while loop will read each page
        #print(count)
        pageObj = pdfReader.getPage(count)
        count +=1
        pagecontent += pageObj.extractText()
    fullcontent.append(pagecontent)
    
#     print(j)
#     print(pagecontent)
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ['/Users/arjun/Downloads\\AJ resume.pdf']
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ...

# %%
count=1
for i in fullcontent:
    
    sub1='a b s t r a c t'
    sub2='Introduction'
    idx1 = i.index(sub1)
    idx2 = i.index(sub2)
    res = ''
    # getting elements in between
    try:
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        print(res);
    except:
        sub2='Background'
        idx2 = i.index(sub2)
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        print(res);
    
    introduction.append(res)
print(introduction)
# Out:
# 1
#
# Resilient  operation  of multi-energy  microgrid  is a critical concept for decarbonization  in modern power system. Its
# goal is to mitigate  the low probability  and high damaging  impacts of electricity  interruptions.  Electrical  vehicles,
# as a key ﬂexibility  provider,  can react to unserved  demand  and autonomously  schedule  their operation  in order
# to provide resilience.  This paper presents  a distributed  control strategy  for a population  of electrical  vehicles
# to enhance  resilience  of an urban energy system experiencing  extreme  contingency.  Speciﬁcally,  an iterative
# algorithm  is developed  to coordinate  the charging/discharging  schedules  of heterogeneous  electrical  vehicles
# aiming at reducing  the essential  load shedding  while considering  the local constraints  and multi-energy  microgrid
# interconnection  capacities.  Additionally,  the gap between  electrical  vehicle energy and the required  energy level
# ...

# %%
# text preprocessing




# download nltk

import nltk

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\arjun\AppData\Roaming\nltk_data...
# ...

# %%
text = introduction
import re

from nltk.corpus import stopwords

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()




corpus = []




for i in range(len(text)):

    r = re.sub('[^a-zA-Z]', ' ', text[i])

    r = r.lower()

    r = r.split()

    r = [word for word in r if word not in stopwords.words('english')]

    r = [lemmatizer.lemmatize(word) for word in r]

    r = ' '.join(r)

    corpus.append(r)
    
introduction=corpus
print(introduction)
# Out:
# ['paint deterioration serious esthetic economic concern attributed microbial ac tivity identifying microbe crucial mitigating deleterious effect paper assessed bacterial community population fresh spoilt water based paint reputable paint company lagos nigeria using culture dependent metage nomic approach gas chromatography mass spectrophotometry gcms used elu cidate component sample bacterial population ranged cfu ml fresh spoilt sample respec tively culture based technique revealed bacillus spp dominant bacteria fresh paint along paenibacillus macerans corynebacterium striatum enterobacter cloaca clostridium sphenoides pseudomonas spp predominant spoilt paint together arthrobacter globiformis azotobacter chroccoccum burkholderia malleus alcaligenes fae cali enterobacter amnigenus bacillus megaterium microbiome sequencing extracted dna spoilt paint revealed rich bacterial diversity surprising archaea pop ulation methanospirillum lacuna belonging phylum euryarchaeota gc m analysis rev
# ...

# %%
import transformers

# %%
from transformers import pipeline

# Load the topic classification model
classifier = pipeline("zero-shot-classification")

# Text to analyze
text = "paint deterioration serious esthetic economic concern attributed microbial activity..."

# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy"]

# Perform zero-shot classification
result = classifier(text, possible_topics)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Predicted Topic: Economy
# Confidence: 0.49

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

# Load a pre-trained model and tokenizer for text classification
model_name = "facebook/bart-large-mnli"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Text to analyze
text = "paint deterioration serious esthetic economic concern attributed microbial activity..."

# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy"]

# Tokenize the text and convert to tensor
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# Make a prediction
with torch.no_grad():
    logits = model(**inputs).logits

# Get the predicted topic
predicted_topic_index = logits.argmax().item()
predicted_topic = possible_topics[predicted_topic_index]

print(f"Predicted Topic: {predicted_topic}")
# Out:
# Predicted Topic: Microbiology

# %%
import transformers

from transformers import pipeline

# Load the topic classification model
classifier = pipeline("zero-shot-classification")

result=classifier(introduction[0],possible_topics)
print(result)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# ...

# %%
#Model 1
from transformers import pipeline
# Load the topic classification model
classifier = pipeline("zero-shot-classification", model="valhalla/distilbart-mnli-12-3")
# Text to analyze
text = "paint deterioration serious esthetic economic concern attributed microbial activity..."
# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy"]

# Perform zero-shot classification
result = classifier(introduction[0], possible_topics)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]
print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(result)
# Out:
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/977M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Predicted Topic: Economy
# Confidence: 0.29
# ...

# %%
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")


# Text to analyze
text = "paint deterioration serious esthetic economic concern attributed microbial activity..."

# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy"]

# Perform zero-shot classification
result = classifier(introduction[0], possible_topics)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(result)
# Out:
# Predicted Topic: Microbiology
# Confidence: 0.35
# ...

# %%
#model 2

#Import libraries
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.figure import Figure
## Class definition
import gensim
from gensim import corpora
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Sample text for analysis
sample_text = """
    Paint deterioration  is a serious esthetic  and economic  concern  attributed  to microbial  ac- 
tivity.Identifying  these microbes  is crucial to mitigating  their deleterious  effects. This paper 
assessed  the bacterial  community  and population  of fresh and spoilt water-based  paints 
from a reputable  paint company  in Lagos, Nigeria using culture-dependent  and metage-  
nomic approaches.  Gas Chromatography  Mass Spectrophotometry  (GCMS)  was used to elu- 
cidate components  of the samples  . The bacterial  population  ranged from 1.4 ×10 6 to 
4.4 ×10 8 and from 2.3 ×10 6 to 6.8 ×10 8 CFU/ml in fresh and spoilt samples  respec- 
tively. Culture-based  technique  revealed  Bacillus spp. as the dominant  bacteria  in fresh 
paint along with Paenibacillus  macerans,  Corynebacterium  striatum,  Enterobacter  cloacae and 
Clostridium  sphenoides  while Pseudomonas  spp. were predominant  in spoilt paints together  
with Arthrobacter  globiformis,  Azotobacter  chroccoccum,  Burkholderia  mallei, Alcaligenes  fae- 
calis, Enterobacter  amnigenus  and Bacillus megaterium  . Microbiome  sequencing  of extracted  
DNA from spoilt paint revealed  a rich bacterial  diversity  and a surprising  archaea  pop- 
ulation of Methanospirillum  lacunae belonging  to phylum  Euryarchaeota.  GC-MS analysis  
revealed  esters as dominant  compounds  in fresh paints while acids and alcohols  suggest 
that degradation  of the components  predominate  in the spoilt paints. Metagenomic  ap- 
proach thus revealed  for the ﬁrst time, the co-existence  of M.lacunae,  an archaea  with other 
bacteria  in paints.
"""

# Tokenize the text and preprocess it
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token not in stopwords.words('english')]
    tokens = [token for token in tokens if token not in string.punctuation]
    return tokens

processed_tokens = preprocess_text(sample_text)

# Create a dictionary from the tokens
dictionary = corpora.Dictionary([processed_tokens])

# Convert tokens to a bag-of-words representation
bow_corpus = [dictionary.doc2bow(processed_tokens)]

# Train an LDA model on the bag-of-words corpus
lda_model = LdaModel(bow_corpus, num_topics=5, id2word=dictionary)

# Print the topics and their keywords
topics = lda_model.print_topics(num_words=5)
topic_output=[]

for topic in topics:
    print(topic)
    topic_output.append(topic)

# Assign topics to the text based on the LDA model
topic_assignments = lda_model.get_document_topics(bow_corpus[0])

# Display the topic assignments
for topic in topic_assignments:
    print(f"Topic {topic[0]}: {topic[1]:.4f}")
    
    
    
print(topic_assignments)
print(topic_output)

topic_words = {topic_id: set(topic.split('"')[1::2]) for topic_id, topic in topic_output}

print(topic_words)
#topic_words=
# Out:
# (0, '0.024*"×10" + 0.021*"spoilt" + 0.019*"fresh" + 0.019*"paint" + 0.018*"paints"')
# (1, '0.022*"paints" + 0.022*"spoilt" + 0.020*"fresh" + 0.018*"revealed" + 0.018*"paint"')
# (2, '0.024*"paints" + 0.024*"spoilt" + 0.022*"fresh" + 0.021*"paint" + 0.020*"revealed"')
# (3, '0.028*"paints" + 0.025*"spoilt" + 0.021*"paint" + 0.021*"revealed" + 0.019*"×10"')
# (4, '0.021*"spoilt" + 0.018*"revealed" + 0.018*"fresh" + 0.018*"paints" + 0.016*"×10"')
# Topic 3: 0.9946
# [(3, 0.9945508)]
# [(0, '0.024*"×10" + 0.021*"spoilt" + 0.019*"fresh" + 0.019*"paint" + 0.018*"paints"'), (1, '0.022*"paints" + 0.022*"spoilt" + 0.020*"fresh" + 0.018*"revealed" + 0.018*"paint"'), (2, '0.024*"paints" + 0.024*"spoilt" + 0.022*"fresh" + 0.021*"paint" + 0.020*"revealed"'), (3, '0.028*"paints" + 0.025*"spoilt" + 0.021*"paint" + 0.021*"revealed" + 0.019*"×10"'), (4, '0.021*"spoilt" + 0.018*"revealed" + 0.018*"fresh" + 0.018*"paints" + 0.016*"×10"')]
# ...

# %%
#model 2 improvement attempt



import gensim
from gensim import corpora
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

from gensim import models
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Sample topics output from the previous code
topics_output = [
    (0, '0.030*"spoilt" + 0.029*"paints" + 0.022*"×10" + 0.020*"paint" + 0.019*"bacterial"'),
(1, '0.027*"revealed" + 0.026*"paints" + 0.023*"paint" + 0.022*"spoilt" + 0.021*"×10"'),
(2, '0.022*"fresh" + 0.016*"spoilt" + 0.016*"×10" + 0.016*"paints" + 0.015*"revealed"'),
(3, '0.018*"×10" + 0.018*"paint" + 0.017*"fresh" + 0.017*"spoilt" + 0.016*"paints"'),
(4, '0.022*"spoilt" + 0.017*"fresh" + 0.017*"paints" + 0.016*"revealed" + 0.015*"paint"')
]

# Sample text to predict topic for
sample_text = """
Paint deterioration  is a serious esthetic  and economic  concern  attributed  to microbial  ac- 
tivity.Identifying  these microbes  is crucial to mitigating  their deleterious  effects. This paper 
assessed  the bacterial  community  and population  of fresh and spoilt water-based  paints 
from a reputable  paint company  in Lagos, Nigeria using culture-dependent  and metage-  
nomic approaches.  Gas Chromatography  Mass Spectrophotometry  (GCMS)  was used to elu- 
cidate components  of the samples  . The bacterial  population  ranged from 1.4 ×10 6 to 
4.4 ×10 8 and from 2.3 ×10 6 to 6.8 ×10 8 CFU/ml in fresh and spoilt samples  respec- 
tively. Culture-based  technique  revealed  Bacillus spp. as the dominant  bacteria  in fresh 
paint along with Paenibacillus  macerans,  Corynebacterium  striatum,  Enterobacter  cloacae and 
Clostridium  sphenoides  while Pseudomonas  spp. were predominant  in spoilt paints together  
with Arthrobacter  globiformis,  Azotobacter  chroccoccum,  Burkholderia  mallei, Alcaligenes  fae- 
calis, Enterobacter  amnigenus  and Bacillus megaterium  . Microbiome  sequencing  of extracted  
DNA from spoilt paint revealed  a rich bacterial  diversity  and a surprising  archaea  pop- 
ulation of Methanospirillum  lacunae belonging  to phylum  Euryarchaeota.  GC-MS analysis  
revealed  esters as dominant  compounds  in fresh paints while acids and alcohols  suggest 
that degradation  of the components  predominate  in the spoilt paints. Metagenomic  ap- 
proach thus revealed  for the ﬁrst time, the co-existence  of M.lacunae,  an archaea  with other 
bacteria  in paints."""

# Tokenize and preprocess the text
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token not in stopwords.words('english')]
    tokens = [token for token in tokens if token not in string.punctuation]
    return tokens

processed_tokens = preprocess_text(sample_text)

# Create a dictionary from the processed tokens
dictionary = corpora.Dictionary([processed_tokens])

# Convert tokens to a bag-of-words representation
bow_vector = dictionary.doc2bow(processed_tokens)

# Load the topics output into a format suitable for prediction
topic_words = {topic_id: set(topic.split('"')[1::2]) for topic_id, topic in topics_output}

# Predict the most likely topic based on the words in the text
best_matching_topic = None
best_matching_score = 0

for topic_id, words in topic_words.items():
    matching_score = sum(1 for token in processed_tokens if token in words)
    if matching_score > best_matching_score:
        best_matching_score = matching_score
        best_matching_topic = topic_id

print(f"Predicted topic for the text: {best_matching_topic}")

# %%
#model 2 increment fail


import spacy

# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Define example texts
texts = topic_output

# Define subject labels corresponding to the example texts
subjects = [
    "Math",
    "Biology",
    "History",
    "Physics",
    "Literature","Microbiology","Economy"
]

# Process the example texts using spaCy
doc_texts = [nlp(text) for text in texts]

# Iterate through processed texts and predict subjects based on keywords
predicted_subjects = []
for doc in doc_texts:
    keywords = {
        "math": "Math",
        "biology": "Biology",
        "history": "History",
        "physics": "Physics",
        "literature": "Literature",
        "Microbiology":
    }
    
    predicted_subject = None
    for keyword, subject in keywords.items():
        if keyword in doc.text.lower():
            predicted_subject = subject
            break
    if not predicted_subject:
        predicted_subject = "Unknown"
    
    predicted_subjects.append(predicted_subject)

# Print predicted subjects for each text
for text, predicted_subject in zip(texts, predicted_subjects):
    print(f"Text: {text}")
    print(f"Predicted Subject: {predicted_subject}")
    print("-" * 20)

# %%
#model 3


#Doesn't perform



import torch
from transformers import BertTokenizer, BertForSequenceClassification

# Load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

# Define example texts
texts = [
    """Paint deterioration  is a serious esthetic  and economic  concern  attributed  to microbial  ac- 
tivity.Identifying  these microbes  is crucial to mitigating  their deleterious  effects. This paper 
assessed  the bacterial  community  and population  of fresh and spoilt water-based  paints 
from a reputable  paint company  in Lagos, Nigeria using culture-dependent  and metage-  
nomic approaches.  Gas Chromatography  Mass Spectrophotometry  (GCMS)  was used to elu- 
cidate components  of the samples  . The bacterial  population  ranged from 1.4 ×10 6 to 
4.4 ×10 8 and from 2.3 ×10 6 to 6.8 ×10 8 CFU/ml in fresh and spoilt samples  respec- 
tively. Culture-based  technique  revealed  Bacillus spp. as the dominant  bacteria  in fresh 
paint along with Paenibacillus  macerans,  Corynebacterium  striatum,  Enterobacter  cloacae and 
Clostridium  sphenoides  while Pseudomonas  spp. were predominant  in spoilt paints together  
with Arthrobacter  globiformis,  Azotobacter  chroccoccum,  Burkholderia  mallei, Alcaligenes  fae- 
calis, Enterobacter  amnigenus  and Bacillus megaterium  . Microbiome  sequencing  of extracted  
DNA from spoilt paint revealed  a rich bacterial  diversity  and a surprising  archaea  pop- 
ulation of Methanospirillum  lacunae belonging  to phylum  Euryarchaeota.  GC-MS analysis  
revealed  esters as dominant  compounds  in fresh paints while acids and alcohols  suggest 
that degradation  of the components  predominate  in the spoilt paints. Metagenomic  ap- 
proach thus revealed  for the ﬁrst time, the co-existence  of M.lacunae,  an archaea  with other 
bacteria  in paints."""
]

# Tokenize and prepare input for the model
inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")

# Classify texts using the pre-trained BERT model
with torch.no_grad():
    logits = model(**inputs).logits

# Apply softmax to get probabilities
probs = torch.softmax(logits, dim=1)

# Define labels
labels = [   
    "History",
    "Physics",
    "Literature","Microbiology","Economy","Biology"]

# Determine predicted labels
predicted_labels = [labels[idx] for idx in probs.argmax(dim=1)]

# Print predicted categories for each text
for text, predicted_label in zip(texts, predicted_labels):
    print(f"Text: {text}")
    print(f"Predicted Label: {predicted_label}")
    print("-" * 20)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Text: Paint deterioration  is a serious esthetic  and economic  concern  attributed  to microbial  ac-
# tivity.Identifying  these microbes  is crucial to mitigating  their deleterious  effects. This paper
# assessed  the bacterial  community  and population  of fresh and spoilt water-based  paints
# from a reputable  paint company  in Lagos, Nigeria using culture-dependent  and metage-
# nomic approaches.  Gas Chromatography  Mass Spectrophotometry  (GCMS)  was used to elu-
# cidate components  of the samples  . The bacterial  population  ranged from 1.4 ×10 6 to
# 4.4 ×10 8 and from 2.3 ×10 6 to 6.8 ×10 8 CFU/ml in fresh and spoilt samples  respec-
# ...

# %%
#model 4

import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load pre-trained model and tokenizer
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
num_topics = 5  # Change this to the number of topics in your classification task
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=num_topics)

# Example text
text = """paint deterioration serious esthetic economic concern attributed microbial ac tivity identifying microbe crucial mitigating deleterious effect paper assessed bacterial community population fresh spoilt water based paint reputable paint company lagos nigeria using culture dependent metage nomic approach gas chromatography mass spectrophotometry gcms used elu cidate component sample bacterial population ranged cfu ml fresh spoilt sample respec tively culture based technique revealed bacillus spp dominant bacteria fresh paint along paenibacillus macerans corynebacterium striatum enterobacter cloaca clostridium sphenoides pseudomonas spp predominant spoilt paint together arthrobacter globiformis azotobacter chroccoccum burkholderia malleus alcaligenes fae cali enterobacter amnigenus bacillus megaterium microbiome sequencing extracted dna spoilt paint revealed rich bacterial diversity surprising archaea pop ulation methanospirillum lacuna belonging phylum euryarchaeota gc m analysis revealed ester dominant compound fresh paint acid alcohol suggest degradation component predominate spoilt paint metagenomic ap proach thus revealed rst time co existence lacuna archaea bacteria paint author published elsevier b v behalf african institute mathematical science next 
einstein initiative open access article cc nc nd license http creativecommons org license nc nd"""

# Tokenize and predict
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
outputs = model(**inputs)
predicted_label = torch.argmax(outputs.logits, dim=1).item()

# Map label index to actual topic labels
topic_labels = ["Environment", "Science", "Health", "Microbiology", "Economy"]
predicted_topic = topic_labels[predicted_label]
print("Predicted Topic:", predicted_topic)

# %%
#bulk run
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")




# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry",x "Economy","Physics","Astronomy","Biology","Agriculture"]

results_list=[]
# Perform zero-shot classification
for  i in range(59):
    result = classifier(introduction[i], possible_topics)
    results_list.append(result)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(results_list)
# Out:
# Predicted Topic: Arts
# Confidence: 0.25
# ...

# %%
#all_results=results_list

# with open("results.txt") as file:
#     all_results=file.read()
#     #print(all_results)
# with open("results.txt") as file:
#     results_list=file.readlines()    
    
import ast

with open('results.txt') as f:
    data = ast.literal_eval(f.read())
print(data[0]["labels"])
# Out:
# ['Microbiology', 'Economy', 'Chemistry', 'Arts', 'Biology', 'Physics', 'Astronomy', 'Agriculture']

# %%
scoreslist=[]
for i in range(59):
    scoreslist.append(data[i]["scores"])

    
print(scoreslist)
# Out:
# [[0.2835400402545929, 0.28130173683166504, 0.1367896944284439, 0.1163107380270958, 0.11102451384067535, 0.02982107736170292, 0.026609931141138077, 0.014602330513298512], [0.2835400402545929, 0.28130173683166504, 0.1367896944284439, 0.1163107380270958, 0.11102451384067535, 0.02982107736170292, 0.026609931141138077, 0.014602330513298512], [0.5994393825531006, 0.08077636361122131, 0.07080674916505814, 0.06541187316179276, 0.05384569242596626, 0.04623968154191971, 0.04247324913740158, 0.04100700095295906], [0.4705437421798706, 0.19441835582256317, 0.09385461360216141, 0.06310809403657913, 0.05775478109717369, 0.04927758499979973, 0.036233846098184586, 0.03480898588895798], [0.42925193905830383, 0.15388210117816925, 0.1480807363986969, 0.10360746085643768, 0.05493388697504997, 0.0441475585103035, 0.03579946979880333, 0.03029686212539673], [0.23269203305244446, 0.22483624517917633, 0.15948142111301422, 0.12871398031711578, 0.11168155074119568, 0.061367668211460114, 0.053709082305431366, 0.
# ...

# %%
#principal component analysis dimensionality reduction to 2 dimemsions
import numpy as np
from sklearn.decomposition import PCA


# Reshape the data to a single column matrix (8x1)
data = np.array(scoreslist)

# Initialize PCA with the number of components you want to retain
num_components = 2  # You can choose the number of components you want to keep
pca = PCA(n_components=num_components)

# Fit the PCA model and transform the data
data_pca_d2 = pca.fit_transform(data)

# The transformed data will have reduced dimensions
print(data_pca_d2)
# Out:
# [[-0.12107013  0.07080556]
#  [-0.12107013  0.07080556]
#  [ 0.24559325 -0.05314954]
#  [ 0.0949885   0.03167073]
#  [ 0.0491463  -0.02312136]
#  [-0.16445188 -0.00462292]
#  [-0.1514108   0.02123297]
#  [-0.01099545  0.01566128]
#  [-0.03865069  0.01670895]
#  [-0.15151751 -0.00663405]
#  [ 0.01939324 -0.06591996]
#  [-0.05349178  0.03290498]
#  [-0.06571899 -0.02727363]
#  [-0.11746389 -0.04309806]
#  [-0.05669119  0.13763735]
#  [ 0.23679953 -0.01980204]
#  [-0.07802642 -0.02903555]
#  [ 0.38564753 -0.0179363 ]
#  [-0.0989124  -0.02307325]
#  [-0.03987089 -0.00919109]
#  [ 0.14455577 -0.05712109]
#  [ 0.18569777  0.06730665]
#  [ 0.00187121  0.04869578]
#  [-0.1398257   0.02280333]
#  [-0.16048281 -0.00268956]
#  [ 0.01042239 -0.04945412]
#  [-0.06812881 -0.02814888]
#  [ 0.16638569 -0.03689551]
#  [-0.16059503 -0.02204969]
#  [ 0.20959092  0.01291312]
#  [-0.08271241  0.10364956]
#  [-0.00132942  0.01416062]
#  [-0.19778708 -0.04470858]
#  [-0.17982192 -0.04882491]
# ...

# %%
#reduce it further
# Reshape the data to a single column matrix (8x1)
data = np.array(data_pca)

# Initialize PCA with the number of components you want to retain
num_components = 1  # You can choose the number of components you want to keep
pca = PCA(n_components=num_components)

# Fit the PCA model and transform the data
data_pca = pca.fit_transform(data)

# The transformed data will have reduced dimensions
print(data_pca)
# Out:
# [[-0.12107013]
#  [-0.12107013]
#  [ 0.24559325]
#  [ 0.0949885 ]
#  [ 0.0491463 ]
#  [-0.16445188]
#  [-0.1514108 ]
#  [-0.01099545]
#  [-0.03865069]
#  [-0.15151751]
#  [ 0.01939324]
#  [-0.05349178]
#  [-0.06571899]
#  [-0.11746389]
#  [-0.05669119]
#  [ 0.23679953]
#  [-0.07802642]
#  [ 0.38564753]
#  [-0.0989124 ]
#  [-0.03987089]
#  [ 0.14455577]
#  [ 0.18569777]
#  [ 0.00187121]
#  [-0.1398257 ]
#  [-0.16048281]
#  [ 0.01042239]
#  [-0.06812881]
#  [ 0.16638569]
#  [-0.16059503]
#  [ 0.20959092]
#  [-0.08271241]
#  [-0.00132942]
#  [-0.19778708]
#  [-0.17982192]
#  [-0.0238406 ]
#  [-0.04967413]
#  [ 0.14178461]
#  [ 0.11502819]
#  [ 0.12773695]
#  [ 0.04316862]
#  [ 0.09050419]
#  [-0.0456971 ]
#  [-0.1088556 ]
#  [ 0.04430191]
#  [-0.12856939]
#  [ 0.03952612]
#  [-0.09502835]
#  [ 0.00686985]
#  [ 0.21649544]
#  [-0.06276625]
#  [ 0.0261877 ]
#  [ 0.00403141]
#  [-0.06696454]
#  [ 0.22520914]
#  [-0.09574847]
#  [-0.1439136 ]
#  [-0.07578384]
#  [ 0.44869889]
# ...

# %%
#results

import matplotlib.pyplot as plt

# Data
subjects = data[0]["labels"]
scores =scoreslist[0]
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.barh(subjects, scores, color='skyblue')
plt.xlabel('Scores')
plt.title('Subject Scores')
plt.gca().invert_yaxis()  # Reverse the order of subjects for better readability
plt.show()

# %%
#results 2
import matplotlib.pyplot as plt
import numpy as np

# Data for three files
file1_data = scoreslist[0]
file2_data = scoreslist[1]
file3_data = scoreslist[2]

# Subjects
subjects = data[0]["labels"]

# X-axis positions for the bars
x = np.arange(len(subjects))

# Bar width for better separation
bar_width = 0.25

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot data from file 1
ax.bar(x - bar_width, file1_data, width=bar_width, label='File 1', color='skyblue')

# Plot data from file 2
ax.bar(x, file2_data, width=bar_width, label='File 2', color='lightcoral')

# Plot data from file 3
ax.bar(x + bar_width, file3_data, width=bar_width, label='File 3', color='lightgreen')

# Set labels and title
ax.set_xlabel('Subjects')
ax.set_ylabel('Scores')
ax.set_title('Subject Scores for Three Files')
ax.set_xticks(x)
ax.set_xticklabels(subjects, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
#Science Map


import matplotlib.pyplot as plt

# Data points
points=data_pca_d2

# Extract X and Y coordinates
x_coordinates = [point[0] for point in points]
y_coordinates = [point[1] for point in points]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_coordinates, y_coordinates, marker='o', c='b', label='Points')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Points')

# Show the plot
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans

points=np.array(data_pca_d2)

# Number of clusters
k = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(points)

# Extract cluster centers
cluster_centers = kmeans.cluster_centers_

# Plot the data points with cluster assignments
plt.figure(figsize=(8, 6))

# Scatter plot for each cluster
for i in range(k):
    plt.scatter(points[cluster_labels == i, 0], points[cluster_labels == i, 1], label=f'Cluster {i+1}')

# Plot cluster centers
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', label='Cluster Centers')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering')

# Show the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#journal 2
import glob
import os

file_list=glob.glob("/Users/arjun/Downloads/dataset1/*.pdf")
import PyPDF2
import re
fullcontent=[]
for j in file_list: 
    #pdfFileObj = open(r"C:\Users\arjun\Downloads\dataset\A-first-report-on-the-identification-of-a-novel-archaea--Methan_2022_Scienti.pdf", 'rb')
    pdfReader = PyPDF2.PdfFileReader(j)
    num_pages = pdfReader.numPages      
    count = 0
    pagecontent = ""                                                   
    while count < num_pages: #The while loop will read each page
        #print(count)
        pageObj = pdfReader.getPage(count)
        count +=1
        pagecontent += pageObj.extractText()
    fullcontent.append(pagecontent)
    
text = introduction


count=1
for i in fullcontent:
    
    sub1='a b s t r a c t'
    sub2='Introduction'
    idx1 = i.index(sub1)
    idx2 = i.index(sub2)
    res = ''
    # getting elements in between
    try:
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        print(res);
    except:
        sub2='Background'
        idx2 = i.index(sub2)
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        print(res);
    
    introduction.append(res)
print(introduction)

import re

from nltk.corpus import stopwords

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()




corpus = []




for i in range(len(text)):

    r = re.sub('[^a-zA-Z]', ' ', text[i])

    r = r.lower()

    r = r.split()

    r = [word for word in r if word not in stopwords.words('english')]

    r = [lemmatizer.lemmatize(word) for word in r]

    r = ' '.join(r)

    corpus.append(r)
    
introduction=corpus
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# 1
#
# ...

# %%
from transformers import pipeline

# Load the topic classification model
classifier = pipeline("zero-shot-classification", model="valhalla/distilbart-mnli-12-3")


# Text to analyze
text = introduction[0]

# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy"]

# Perform zero-shot classification
result = classifier(introduction[0], possible_topics)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(result)
# Out:
# Predicted Topic: Economy
# Confidence: 0.29
# ...

# %%
#bulk run journal 2
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")




possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy","Physics","Astronomy","Biology","Agriculture"]

results_list=[]
# Perform zero-shot classification
for  i in range(12):
    result = classifier(introduction[i], possible_topics)
    results_list.append(result)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(results_list)
# Out:
# Predicted Topic: Arts
# Confidence: 0.35
# ...

# %%
import ast

with open('results 2.txt') as f:
    data = ast.literal_eval(f.read())
print(data[0]["labels"])
# Out:
# ['Economy', 'Microbiology', 'Chemistry', 'Arts', 'Biology', 'Physics', 'Astronomy', 'Agriculture']

# %%
scoreslist2=[]
for i in range(12):
    scoreslist2.append(data[i]["scores"])
    scoreslist.append(data[i]["scores"])


    
print(scoreslist2)
# Out:
# [[0.2835400402545929, 0.28130173683166504, 0.1367896944284439, 0.1163107380270958, 0.11102451384067535, 0.02982107736170292, 0.026609931141138077, 0.014602330513298512], [0.2835400402545929, 0.28130173683166504, 0.1367896944284439, 0.1163107380270958, 0.11102451384067535, 0.02982107736170292, 0.026609931141138077, 0.014602330513298512], [0.5994393825531006, 0.08077636361122131, 0.07080674916505814, 0.06541187316179276, 0.05384569242596626, 0.04623968154191971, 0.04247324913740158, 0.04100700095295906], [0.4705437421798706, 0.19441835582256317, 0.09385461360216141, 0.06310809403657913, 0.05775478109717369, 0.04927758499979973, 0.036233846098184586, 0.03480898588895798], [0.42925193905830383, 0.15388210117816925, 0.1480807363986969, 0.10360746085643768, 0.05493388697504997, 0.0441475585103035, 0.03579946979880333, 0.03029686212539673], [0.23269203305244446, 0.22483624517917633, 0.15948142111301422, 0.12871398031711578, 0.11168155074119568, 0.061367668211460114, 0.053709082305431366, 0.
# ...

# %%
#principal component analysis dimensionality reduction to 2 dimemsions
import numpy as np
from sklearn.decomposition import PCA


# Reshape the data to a single column matrix (8x1)
data = np.array(scoreslist2)

# Initialize PCA with the number of components you want to retain
num_components = 2  # You can choose the number of components you want to keep
pca = PCA(n_components=num_components)

# Fit the PCA model and transform the data
data2_pca_d2 = pca.fit_transform(data)

# The transformed data will have reduced dimensions
print(data2_pca_d2)
# Out:
# [[-0.166626   -0.02799958]
#  [-0.0719103   0.00525526]
#  [-0.10682137 -0.008719  ]
#  [ 0.53079312  0.03774126]
#  [-0.15620332  0.03706538]
#  [-0.00648331 -0.05478558]
#  [ 0.20676893 -0.03240863]
#  [ 0.08019414 -0.06275636]
#  [-0.09330932  0.06998015]
#  [-0.09969379 -0.01034249]
#  [-0.03003846  0.02624306]
#  [-0.08667032  0.02072652]]

# %%
#Science Map


import matplotlib.pyplot as plt

# Data points
points=data2_pca_d2

# Extract X and Y coordinates
x_coordinates = [point[0] for point in points]
y_coordinates = [point[1] for point in points]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_coordinates, y_coordinates, marker='o', c='b', label='Points')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Points')

# Show the plot
plt.grid(True)
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans

points=np.array(data2_pca_d2)

# Number of clusters
k = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(points)

# Extract cluster centers
cluster_centers = kmeans.cluster_centers_

# Plot the data points with cluster assignments
plt.figure(figsize=(8, 6))

# Scatter plot for each cluster
for i in range(k):
    plt.scatter(points[cluster_labels == i, 0], points[cluster_labels == i, 1], label=f'Cluster {i+1}')

# Plot cluster centers
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', label='Cluster Centers')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering')

# Show the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#combined map

#principal component analysis dimensionality reduction to 2 dimemsions
import numpy as np
from sklearn.decomposition import PCA


# Reshape the data to a single column matrix (8x1)

data = np.array(scoreslist)

# Initialize PCA with the number of components you want to retain
num_components = 2  # You can choose the number of components you want to keep
pca = PCA(n_components=num_components)

# Fit the PCA model and transform the data
data2_pca_d2 = pca.fit_transform(data)

# The transformed data will have reduced dimensions


from sklearn.cluster import KMeans

points=np.array(data_pca_d2)

# Number of clusters
k = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(points)

# Extract cluster centers
cluster_centers = kmeans.cluster_centers_

# Plot the data points with cluster assignments
plt.figure(figsize=(8, 6))

# Scatter plot for each cluster
for i in range(k):
    plt.scatter(points[cluster_labels == i, 0], points[cluster_labels == i, 1], label=f'Cluster {i+1}')

# Plot cluster centers
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', label='Cluster Centers')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering')

# Show the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
print(len(scoreslist))
# Out:
# 71

# %%
#User files
import tkinter as tk
from tkinter import filedialog

# Create a Tkinter window for file selection dialog
root = tk.Tk()
root.withdraw()  # Hide the main window

# Prompt the user to select a file
file_path = filedialog.askopenfilename()

if file_path:
    # Print the selected file path
    print("Selected file:", file_path)
else:
    print("No file selected.")

# Close the Tkinter window
root.destroy()
# Out:
# Selected file: C:/Users/arjun/Downloads/A-distributed-robust-control-strategy-for-electric-vehicl_2023_Advances-in-A.pdf

# %%
import glob
import os
print("Selected file:", file_path)
file_list=file_path
import PyPDF2
import re
fullcontent=[]


pdfReader = PyPDF2.PdfFileReader(file_list)
num_pages = pdfReader.numPages      
count = 0
pagecontent = ""                                                   
while count < num_pages: #The while loop will read each page
    #print(count)
    pageObj = pdfReader.getPage(count)
    count +=1
    pagecontent += pageObj.extractText()
fullcontent=[]
fullcontent.append(pagecontent)

count=1
for i in fullcontent:
    
    sub1='a b s t r a c t'
    sub2='Introduction'
    idx1 = i.index(sub1)
    idx2 = i.index(sub2)
    res = ''
    # getting elements in between
    try:
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        
    except:
        sub2='Background'
        idx2 = i.index(sub2)
        for idx in range(idx1 + len(sub1) + 1, idx2):
            res = res + i[idx]
        print(count)
        count=count+1
        
    introduction=[]
    introduction.append(res)
print(introduction)

text = introduction
import re

from nltk.corpus import stopwords

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()




corpus = []




for i in range(len(text)):

    r = re.sub('[^a-zA-Z]', ' ', text[i])

    r = r.lower()

    r = r.split()

    r = [word for word in r if word not in stopwords.words('english')]

    r = [lemmatizer.lemmatize(word) for word in r]

    r = ' '.join(r)

    corpus.append(r)
    
introduction=corpus
print(introduction)

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")




# Possible topics/categories
possible_topics = ["Arts", "Microbiology", "Chemistry", "Economy","Physics","Astronomy","Biology","Agriculture"]

results_list=[]
# Perform zero-shot classification
for  i in range(1):
    result = classifier(introduction[i], possible_topics)
    results_list.append(result)

# Extract the most likely topic
predicted_topic = result["labels"][0]
confidence = result["scores"][0]

print(f"Predicted Topic: {predicted_topic}")
print(f"Confidence: {confidence:.2f}")
print(results_list)
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Selected file: C:/Users/arjun/Downloads/A-distributed-robust-control-strategy-for-electric-vehicl_2023_Advances-in-A.pdf
# 1
# ...

# %%
print(result["scores"])
avg=(sum(result["scores"])/len(result["scores"]))
print(avg)
# Out:
# [0.3625330924987793, 0.22173886001110077, 0.15501299500465393, 0.07377695292234421, 0.0701586902141571, 0.058205295354127884, 0.038198668509721756, 0.02037547342479229]
# 0.12500000349245965

# %%
#combined map

#principal component analysis dimensionality reduction to 2 dimemsions
import numpy as np
from sklearn.decomposition import PCA


# Reshape the data to a single column matrix (8x1)

data = np.array(scoreslist)

# Initialize PCA with the number of components you want to retain
num_components = 2  # You can choose the number of components you want to keep
pca = PCA(n_components=num_components)

# Fit the PCA model and transform the data
data2_pca_d2 = pca.fit_transform(data)

# The transformed data will have reduced dimensions


from sklearn.cluster import KMeans

points=np.array(data_pca_d2)

# Number of clusters
k = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
cluster_labels = kmeans.fit_predict(points)

# Extract cluster centers
cluster_centers = kmeans.cluster_centers_

# Plot the data points with cluster assignments
plt.figure(figsize=(8, 6))

# Scatter plot for each cluster
for i in range(k):
    plt.scatter(points[cluster_labels == i, 0], points[cluster_labels == i, 1], label=f'Cluster {i+1}')

# Plot cluster centers
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', label='Cluster Centers')

plt.scatter(avg,0, c='magenta', marker='o', label='user file')
# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('K-Means Clustering')

# Show the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
# Out:
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\arjun\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
